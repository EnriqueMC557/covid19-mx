# %%
import sys

import tensorflow as tf
import autokeras as ak

from IPython.display import Image

from keras_visualizer import visualizer

sys.path.append("..")

from utils import paths

# %%
experiments = [
    "experiment_20230711_222446",  # 15 1024 16 1
    "experiment_20230711_222532",  # 15 32 32 1
    "experiment_20230711_222628",  # 15 256 128 1
    # "experiment_20230711_222726",  # 15 32 32 1
    # "experiment_20230711_222803",  # 15 32 32 1
    # "experiment_20230711_222838",  # 15 32 32 1
    "experiment_20230711_222914",  # 15 32 64 1
    # "experiment_20230711_223003",  # 15 32 32 1
    "experiment_20230711_223049",  # 15 256 16 32 1
    # "experiment_20230711_223200",  # 15 32 32 1
]

# %%
def plot_model(model_name):
    model_ = tf.keras.models.load_model(f"{paths.MODELS_PATH}/{model_name}")
    visualizer(model_, file_format='png', file_name=f"{paths.FIGURES_PATH}/models/{model_name}")

# %%
plot_model(experiments[0])
Image(f"{paths.FIGURES_PATH}/models/{experiments[0]}.png")

# %%
plot_model(experiments[1])
Image(f"{paths.FIGURES_PATH}/models/{experiments[1]}.png")

# %%
plot_model(experiments[2])
Image(f"{paths.FIGURES_PATH}/models/{experiments[2]}.png")

# %%
plot_model(experiments[3])
Image(f"{paths.FIGURES_PATH}/models/{experiments[3]}.png")

# %%
plot_model(experiments[4])
Image(f"{paths.FIGURES_PATH}/models/{experiments[4]}.png")
